# %% [markdown]
# Input is called as Arguments
# Python is case Sensitive
#
# Built in methods for Search:
#
# find("<word>") ---> it will check the index of starting character index of word, if word does not exist then it will return -1 as output so it say it is not found
#
# count(<char or word>) ---> it will count the number of occurance in the given sentence
# 0 ---> not found, if found it gives the count
#
# startsith("<word>")  ---> it will give True/False
# If matched: True as output else False
#
# endswith(<"word">) ---> it will give True/False
# If matched: True as output else False
#
# in -> True/False ---> it will checks or search the words in sentence, it is case sensitive(
#
# Replace Methods:
#
# replace(old, new)
#
#
# Split and Join
#
# Split is used to convert string to list
# split(",")
#
# Join is used to convert list to String
# ",".join(<list>)
