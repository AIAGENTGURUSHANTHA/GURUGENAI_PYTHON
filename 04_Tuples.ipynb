# %%
#Tuples ----> The data can never be changed, it is immutable, we can not add or remove elements from a tuple, 
# we can not change the value of an element in a tuple, we can not sort a tuple, we can not reverse a tuple, 
# we can not slice a tuple, we can not concatenate a tuple, we can not repeat a tuple, 
# we can not check if an element is in a tuple, we can not get the index of an element in a tuple, 
# we can not get the count of an element in a tuple, we can not convert a tuple to a list,
#  we can not convert a list to a tuple, we can not convert a tuple to a set, we can not convert a set to a tuple, 
# we can not convert a tuple to a dictionary, we can not convert a dictionary to a tuple

#List ---> []
#Tuple --> ()

days_week = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday") # tuple -> Days of the week will never change, 
#so we can use a tuple to store them

months_year = ("January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December") # tuple -> Months of the year will never change,

dhoni_stats = ("MS Dhoni", 1981, "Wicket Keeper", "Right Handed", 10000, 50.57) # tuple -> Dhoni's stats will never change, so we can use a tuple to store them

#yaml -> for configuration we will use tuples, because the data will never change, so we can use a tuple to store them
# for password we will use a tuple 
# 
print(f"Dhoni Average: {dhoni_stats[-1]}") # accessing the 6th element of the tuple, which is the average

#days_week[0] = "Holiday" # this will give an error, because we can not change the value of an element in a tuple, it is immutable
#in Tuples we can access only
# we cannot change, insert, delete, sort, reverse, slice, concatenate, repeat, check if an element is in a tuple, 
# get the index of an element in a tuple, get the count of an element in a tuple, convert a tuple to a list, 
# convert a list to a tuple, convert a tuple to a set, convert a set to a tuple, convert a tuple to a dictionary, 
# convert a dictionary to a tuple

#whole tuple can be converted to list and do our manupulations and then convert it back to tuple

print(f"Days count: {len(days_week)}") # getting the length of the tuple, which is 7

print(f"Is Monday in days_week? {'Monday' in days_week}") # checking if an element is in the tuple, which is True

#unpacking a tuple into variables -> with same index order, we can unpack a tuple into variables
name, year,role, batting, runs, average = dhoni_stats # unpacking the tuple into variables, 
#but we have to make sure that the number of variables is equal to the number of elements in the tuple

print(f"unpacked items are {name} is a {role} with average of {average}")
# Out:
# Dhoni Average: 50.57
# Days count: 7
# Is Monday in days_week? True
# unpacked items are MS Dhoni is a Wicket Keeper with average of 50.57

# %%
# List                                                              Tuple
# []                                                                ()
# data can be changed                                               data cannot be changed
# speed is slower                                                   speed is faster
# data can be added, removed, changed                               data cannot be added, removed, changed
# [1, 2, 3]                                                         (1, 2, 3)
# extend() method can be used to add elements to a list,            but not to a tuple

# %%
# append() method can be used to add elements to a list, but not to a tuple
# insert() method can be used to add elements to a list, but not to a tuple
# extend() method can be used to add elements to a list, but not to a tuple
# remove() method can be used to remove elements from a list, but not to a tuple
# pop() method can be used to remove elements from a list, but not to a tuple
# pop(i) method can be used to remove elements from a list, but not to a tuple
# sort() method can be used to sort elements in a list, but not to a tuple
# sorted() method can be used to sort elements in a list, but not to a tuple
# sort(reverse=True) method can be used to sort elements in a list, but not to a tuple
# count() method can be used to count the occurrences of an element in a tuple
# # index() method can be used to get the index of an element in a tuple
# copy() method can be used to create a copy of a list, but not to a tuple
# len(list) method can be used to get the length of a list, but not to a tuple
# x in list method can be used to check if an element is in a list, but not to a tuple
# Out:
#   Cell In[12], line 12
#     copy() method can be used to create a copy of a list, but not to a tuple
#            ^
# SyntaxError: invalid syntax
