# %% [markdown]
# Python
#
# General pupose language similar to English
#
# Contents:
# Basic: Data Types(string, int, float, bool, none)
#
#        Strings,
#
#        Lists, ()
#
#        Tuples,
#
#        Dictionary,
#
#        Sets
#
#        Conditions,
#
#        Loops,
#
#        Functions,
#
#        Exceptions,
#
#        Files
# OOPS Basics: Encapsulation, Inheritance, Polymorphism
#
# Advanced Python: Comprehension, Lambda, map(), Filter(), Zip(), Sorted()
#                  Decorators and Generators
#
# Python for AI: Multithreading, Multiprocessing, Asyncio, Pydantic

# %% [markdown]
# AI Foundations: AI/ML/DL/Generative AI
#
# Prompt Engineering
#
# AI Hallucinations, Identification methodologies
#
# AI API based, Local LLM Model
#
# AI vs ML vs DL vs GenAI
#
# Evolution of foundation models -> 1967 AI started
# LLM Lifecycle (pretrain -> fine-tune ->RAG -> Inference)
# Prompt patterns (Role based, Few shot, Chain of Thought (CoT))
# Temperature & Top-P tuning
# Context management
# Hallucination basics
# Responsible AI concepts
# API vs Local LLM Comparison
# Running Ollama locally (intro level)
# CPU vs GPU fundamentals

# %% [markdown]
# RAG Systems
#
# Chatbots
#
# LangChain Community
#
# Vector DB
#
# Simple RAG System
# Queue based RAG system
# Sync and Async RAG system
# Embeddings : OpenAI(Chat GPT), Google(Gemini, Gemma), Anthropic(Claude(opus,haiku))
# Chunkings Strategies, Table, Text, Images->Multimodal Systems
#
# Retrieval:Symantic Search
# BM25  match
#
# Evaluation methods

# %% [markdown]
# AI Agents
#
# What is an Agent
#
# Agent Components
#
# Tools integration
#
# Simple memory
#
# Single Agent workflow

# %% [markdown]
# No Code Low Code
#
# N8n tool
#
# Multi step AI Agent System
#
# RAG System
#
# External tools

# %% [markdown]
# Advanced RAG
#
# MCP
#
# Multi agent System
#
# Agentic AI
#
# Its Maintenance and Evalation

# %% [markdown]
# Install particular python from python.org
#
# Create the virtual environment
# Windows:
# python -m venv .venv
#
# macOS:
# python3 -m venv .venv
#
# Activate the Virtual Environment
# Windows (PowerShell)
# .\.venv\Scripts\Activate.ps1
# .\.venv\Scripts\activate
#
# windows deactivation
# deactivate
#
# macOS / Linux
# source .venv/bin/activate
